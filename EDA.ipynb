# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C://kaoutar//DataWerhouse//Projet//linkedin_jobs_20260318_0312.csv")
data.head()
# Out:
#                       title                company  \
# 0      Data Scientist (H/F)           Orange Maroc
# 1  Data Scientist / IA / ML              Capgemini
# 2       AI & Data Scientist  Capgemini Engineering
# 3              R&D Engineer            ALTEN MAROC
# 4     Data Scientist Senior                  Astek
#
#                                location date_posted  \
# 0              Casablanca-Settat, Maroc  2026-03-17
# 1  Casablanca, Casablanca-Settat, Maroc  2026-03-13
# 2  Casablanca, Casablanca-Settat, Maroc  2026-03-13
# 3                Fès, Fès-Meknès, Maroc  2026-03-13
# 4              Casablanca et périphérie  2026-03-11
#
#                                              job_url  search_keyword  \
# 0  https://ma.linkedin.com/jobs/view/data-scienti...  Data Scientist
# 1  https://ma.linkedin.com/jobs/view/data-scienti...  Data Scientist
# 2  https://ma.linkedin.com/jobs/view/ai-data-scie...  Data Scientist
# ...

# %%
data.describe()
# Out:
#                                         title company  \
# count                                     570     570
# unique                                    469     207
# top     Expert technique en tests automatisés  Inetum
# freq                                       14      36
#
#                                     location date_posted  \
# count                                    570         570
# unique                                    36           8
# top     Casablanca, Casablanca-Settat, Maroc  2026-03-13
# freq                                     136         128
#
#                                                   job_url  search_keyword  \
# count                                                 570             570
# unique                                                531              43
# top     https://ma.linkedin.com/jobs/view/c%2B%2B-deve...  Data Scientist
# freq                                                    2              79
#
# ...

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.shape()
#
# NameError: name 'data' is not defined
